# %%
import pandas as pd
import numpy as np

# %%
patent = pd.read_csv("./AI-python-connect/codes/ch_3/part-1/data/sea_managing_raw.csv", encoding="cp949")
patent.head()
# Out:
#   국가코드 DB종류 특허/실용 구분 문헌종류 코드  \
# 0   US   US        P      B2
# 1   US   US        P      A1
# 2   US   US        P      A1
# 3   US   US        P      A1
# 4   US   US        P      B2
#
#                                               발명의 명칭  \
# 0                      Turboengine water wash system
# 1  TREATMENT OF TAILINGS WITH DEIONIZED SILICATE ...
# 2  Method And Apparatus For Treating Tailings Usi...
# 3   METHOD FOR STABILIZING WASTE AND HAZARDOUS WASTE
# 4  Water treatment process and plant using ballas...
#
#                                                   요약  \
# 0  A system for cleaning gas turbine engines is d...
# 1  A process for treating a tailings stream compr...
# 2  There is a method described of treating tailin...
# 3  The invention provides a process for stabilizi...
# 4  A method for treating wastewater using a balla...
#
#                                                대표청구항  청구항 수       출원번호  \
# ...

# %%
patent["출원번호"].isnull().sum()
# Out:
# 0

# %%
df_patent = patent[["출원번호", "Original US Class All[US]"]]
df_patent.head()
# Out:
#         출원번호                          Original US Class All[US]
# 0  11/644784                                134/166.R | 134/138
# 1  13/848244  106/627 | 106/600 | 106/631 | 106/632 | 106/63...
# 2  13/765924                                            204/554
# 3  13/767408                                  588/002 | 588/315
# 4  12/521154  210/709 | 210/711 | 210/712 | 210/713 | 210/71...

# %%
df_patent["Original US Class All[US]"].str.split("|", expand = True).fill
# Out:
#               0          1          2          3          4          5   \
# 0     134/166.R     134/138       None       None       None       None
# 1       106/627    106/600    106/631    106/632    106/634     210/702
# 2        204/554       None       None       None       None       None
# 3       588/002     588/315       None       None       None       None
# 4       210/709    210/711    210/712    210/713    210/714    210/724
# ...          ...        ...        ...        ...        ...        ...
# 1900    075/398    075/399     075/711       None       None       None
# 1901    210/688    210/747    210/912    588/001     588/020       None
# 1902    588/257    588/252     405/129       None       None       None
# 1903    210/732    210/800    210/808    210/533    210/536    210/537
# 1904    210/605    210/613    210/614    210/625     210/903       None
#
#              6          7          8         9   ...    14    15    16    17  \
# ...
